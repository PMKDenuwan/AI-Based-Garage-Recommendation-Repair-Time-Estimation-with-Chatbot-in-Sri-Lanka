# %%
# %pip install pandas scikit-learn numpy matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\hi\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in c:\users\hi\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy in c:\users\hi\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\hi\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: seaborn in c:\users\hi\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hi\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\hi\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hi\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hi\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hi\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hi\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hi\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hi\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hi\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hi\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hi\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\hi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
import pickle

# Load the data using YOUR specific filename
print("📂 Loading dataset...")
df = pd.read_csv('suzukialto_repairtime_dataset.csv') 

print(f"✓ Dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns")
df.head(10)
# Out:
# 📂 Loading dataset...
# ✓ Dataset loaded: 875 rows, 15 columns
#    Record_ID    Car_Model  Model_Year  Mileage_KM Fault_Category  \
# 0          1  Suzuki Alto        2015       50303         Engine
# 1          2  Suzuki Alto        2019      201740         Engine
# 2          3  Suzuki Alto        2013      163706             AC
# 3          4  Suzuki Alto        2019       51420           Body
# 4          5  Suzuki Alto        2021       79380          Brake
# 5          6  Suzuki Alto        2011      210185          Brake
# 6          7  Suzuki Alto        2017      228011     Electrical
# 7          8  Suzuki Alto        2011      216741             AC
# 8          9  Suzuki Alto        2017       37015          Brake
# 9         10  Suzuki Alto        2018      157852           Body
#
#          Fault_Type  Severity      Parts_Required Parts_Availability  \
# 0  Thermostat Stuck  Moderate    Thermostat Valve           In Stock
# 1         Misfiring  Moderate   Spark Plugs/Coils           In Stock
# 2  Blower Fan Issue  Moderate        Blower Motor           In Stock
# 3  Windshield Crack     Minor    Windshield Glass           In Stock
# 4    Brake Pad Wear  Moderate          Brake Pads           In Stock
# 5  ABS Sensor Fault     Minor          ABS Sensor           In Stock
# 6   Headlight Issue     Minor           Bulb/Fuse           In Stock
# 7        No Cooling  Moderate     Refrigerant Gas           In Stock
# 8   Brake Shoe Wear     Minor         Brake Shoes           In Stock
# 9        Rust Patch     Minor  Tinkering/Painting           In Stock
#
#   Garage_Type  Mechanic_Expertise       Location Day_of_Week Time_of_Day  \
# 0       Local                  15     Welipitiya    Saturday     Evening
# 1  Authorized                  17        Walgama      Friday   Afternoon
# 2       Local                  18       Thalalla    Saturday   Afternoon
# 3  Authorized                  14       Kotapola   Wednesday   Afternoon
# 4       Local                  18       Nawimana      Sunday   Afternoon
# 5  Authorized                  15        Gandara   Wednesday     Evening
# 6       Local                  14     Welipitiya   Wednesday   Afternoon
# 7       Local                  15       Kaduwela      Sunday     Morning
# 8       Local                  12       Kaduwela     Tuesday   Afternoon
# 9       Local                   8  Kamburupitiya    Thursday   Afternoon
#
#    Actual_Repair_Hours
# 0                  2.7
# 1                  1.4
# 2                  1.0
# 3                  1.5
# 4                  0.9
# 5                  0.6
# 6                  0.5
# 7                  2.7
# 8                  0.9
# 9                  2.8
